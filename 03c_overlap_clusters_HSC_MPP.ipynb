# %% [markdown]
# ## 03c overlap clusters HSC MPP
#
# this should help with HSC cluster naming
#
# 1) how much overlap in enriched genes between clusters
# 2) differential proportion analysis - how similar are clusters between replicates for both MPPs and LTs
#
# from this paper https://elifesciences.org/articles/43882#s4
#
# done with this docker image:
#
# docker run --rm -d --name test_eva -p 8883:8888 -e JUPYTER_ENABLE_LAB=YES -v /Users/efast/Documents/:/home/jovyan/work r_scanpy:vs5

# %%
#load some packages that are needed for plotting + computation

import math
from matplotlib import pyplot as plt
import pandas as pd
import scipy.stats as stats
import seaborn as sns
# %matplotlib inline

# %%
LT = pd.read_csv('./write/all_LT_clusters.csv')
MPP = pd.read_csv('./write/all_MPP_clusters.csv')

# %%
# read in the list with enriched genes and calculate overlap of pairwise comparison between clusters

results_df_list =[]
results_df = pd.DataFrame()

for k in range(0, 12, 2):
    results_df_list =[]
    for i in range(0, 16, 2):
        mrg = pd.merge(LT, MPP, how='inner', left_on=LT.iloc[:,k], right_on=MPP.iloc[:,i])
        len_m = len(mrg)
        results_df_list.append(len_m)
    
    results_df_list = pd.Series(results_df_list)
    results_df = results_df.append(results_df_list, ignore_index=True)

# %%
results_df
# Out:
#       0     1     2     3     4     5     6    7
# 0   1.0  33.0   0.0   2.0   0.0   1.0   0.0  3.0
# 1  32.0   0.0  42.0   0.0  16.0   4.0   2.0  0.0
# 2   0.0   0.0  30.0   1.0  21.0   2.0   1.0  2.0
# 3   0.0   0.0   3.0   0.0   0.0  86.0  70.0  1.0
# 4   5.0   0.0   5.0   0.0  47.0   1.0   1.0  3.0
# 5   0.0  41.0   0.0  50.0   0.0   0.0  20.0  0.0

# %%
results_df.columns = ['Primed', 'Metabolism', 'Progenitor', 'Cell-cycle', 'Acute-Activation', 'Interferon', 'Interferon cell-cycle','Myeloid']
results_df.index = ['Metabolism', 'Quiescent', 'Activated', 'Interferon', 'Acute-Activation', 'Cell-cycle']

# %%
results_df
# Out:
#                   Primed  Metabolism  Progenitor  Cell-cycle  \
# Metabolism           1.0        33.0         0.0         2.0
# Quiescent           32.0         0.0        42.0         0.0
# Activated            0.0         0.0        30.0         1.0
# Interferon           0.0         0.0         3.0         0.0
# Acute-Activation     5.0         0.0         5.0         0.0
# Cell-cycle           0.0        41.0         0.0        50.0
#
#                   Acute-Activation  Interferon  Interferon cell-cycle  Myeloid
# Metabolism                     0.0         1.0                    0.0      3.0
# Quiescent                     16.0         4.0                    2.0      0.0
# Activated                     21.0         2.0                    1.0      2.0
# Interferon                     0.0        86.0                   70.0      1.0
# Acute-Activation              47.0         1.0                    1.0      3.0
# Cell-cycle                     0.0         0.0                   20.0      0.0

# %%
results_df_p = results_df/100
results_df_p
# Out:
#                   Primed  Metabolism  Progenitor  Cell-cycle  \
# Metabolism          0.01        0.33        0.00        0.02
# Quiescent           0.32        0.00        0.42        0.00
# Activated           0.00        0.00        0.30        0.01
# Interferon          0.00        0.00        0.03        0.00
# Acute-Activation    0.05        0.00        0.05        0.00
# Cell-cycle          0.00        0.41        0.00        0.50
#
#                   Acute-Activation  Interferon  Interferon cell-cycle  Myeloid
# Metabolism                    0.00        0.01                   0.00     0.03
# Quiescent                     0.16        0.04                   0.02     0.00
# Activated                     0.21        0.02                   0.01     0.02
# Interferon                    0.00        0.86                   0.70     0.01
# Acute-Activation              0.47        0.01                   0.01     0.03
# Cell-cycle                    0.00        0.00                   0.20     0.00

# %%
results_df_p.columns.tolist()
# Out:
# ['Primed',
#  'Metabolism',
#  'Progenitor',
#  'Cell-cycle',
#  'Acute-Activation',
#  'Interferon',
#  'Interferon cell-cycle',
#  'Myeloid']

# %%
results_df_p.index.tolist()
# Out:
# ['Metabolism',
#  'Quiescent',
#  'Activated',
#  'Interferon',
#  'Acute-Activation',
#  'Cell-cycle']

# %%
results_df_p = results_df_p[['Progenitor', 'Primed', 'Metabolism', 'Cell-cycle', 'Interferon cell-cycle', 
                 'Interferon', 'Acute-Activation','Myeloid']]
results_df_p = results_df_p.reindex(['Quiescent', 'Activated','Metabolism','Cell-cycle', 'Interferon',
                                     'Acute-Activation'])

# %%
sns.set(font_scale=1.4)

plt.figure(figsize=(12,5))
sns.heatmap(results_df_p.T, annot=True, annot_kws={"size": 16})
plt.yticks(rotation=0, fontsize = 12) 
plt.xticks(rotation=-0, fontsize = 12)
plt.savefig("./figures/overlap_clusters_MPP_LT_all.pdf", dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 2) Differential proportion analysis

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
import seaborn as sb
import scipy.stats as stats

import rpy2.rinterface_lib.callbacks
import logging

from rpy2.robjects import pandas2ri
import anndata2ri

# %%
# Ignore R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

# Automatically convert rpy2 outputs to pandas dataframes
pandas2ri.activate()
anndata2ri.activate()
# %load_ext rpy2.ipython

plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.17.3 scipy==1.3.0 pandas==0.25.3 scikit-learn==0.22.2.post1 statsmodels==0.10.0 python-igraph==0.7.1 louvain==0.6.1

# %%
# %%R
# # Load libraries from correct lib Paths for my environment - ignore this!
# .libPaths(.libPaths()[c(3,2,1)])
#
# # Load all the R libraries we will be using in the notebook
# library(ggplot2)
# library(plyr)
#
# source("diffprop_functions.R");

# %% [markdown]
# ## Comparison LT clusters

# %%
# read csvs, rename columns, merge and transpose
LT = pd.read_csv('./write/LT_cell_numbers.csv', index_col = 0)
LT = LT.T
LT
# Out:
# leiden  Metabolism  Quiescent  Activated  Interferon  Acute-Activation  \
# GCSF        1204.0      937.0      780.0        21.0               0.0
# ct          1865.0     1981.0     1556.0        40.0               0.0
# dmPGE2        83.0       24.0      108.0         0.0             261.0
# indo        1757.0     1816.0     1947.0        58.0               1.0
# pIC          188.0      184.0       58.0       316.0               0.0
#
# leiden  Cell-cycle
# GCSF          42.0
# ct            79.0
# dmPGE2         0.0
# indo          47.0
# pIC            2.0

# %%
# %%R -i LT
# ## Read in file of counts of cells in each population across conditions
#
# obs.counts = as.matrix(LT)
# print(obs.counts)
# Out:
#        Metabolism Quiescent Activated Interferon Acute.Activation Cell.cycle
# GCSF         1204       937       780         21                0         42
# ct           1865      1981      1556         40                0         79
# dmPGE2         83        24       108          0              261          0
# indo         1757      1816      1947         58                1         47
# pIC           188       184        58        316                0          2

# %%
# %%R
#
# ## Run an example using error (p) of 0.05 and with 100,000 iterations
# tip.exp <- generateNull(obs.counts, n=100000, p=0.1);     # Generate the null distribution based on sampling
#
# print(obs.counts/apply(obs.counts, 1, sum))
# Out:
# [1] 1000
# [1] 2000
# [1] 3000
# [1] 4000
# [1] 5000
# [1] 6000
# [1] 7000
# [1] 8000
# [1] 9000
# [1] 10000
# [1] 11000
# [1] 12000
# [1] 13000
# [1] 14000
# [1] 15000
# [1] 16000
# [1] 17000
# [1] 18000
# [1] 19000
# [1] 20000
# [1] 21000
# [1] 22000
# [1] 23000
# [1] 24000
# [1] 25000
# [1] 26000
# [1] 27000
# [1] 28000
# [1] 29000
# [1] 30000
# [1] 31000
# [1] 32000
# [1] 33000
# [1] 34000
# [1] 35000
# [1] 36000
# [1] 37000
# [1] 38000
# [1] 39000
# [1] 40000
# [1] 41000
# [1] 42000
# [1] 43000
# [1] 44000
# [1] 45000
# [1] 46000
# [1] 47000
# [1] 48000
# [1] 49000
# [1] 50000
# [1] 51000
# [1] 52000
# [1] 53000
# [1] 54000
# [1] 55000
# [1] 56000
# [1] 57000
# [1] 58000
# [1] 59000
# [1] 60000
# [1] 61000
# [1] 62000
# [1] 63000
# [1] 64000
# [1] 65000
# [1] 66000
# [1] 67000
# [1] 68000
# [1] 69000
# [1] 70000
# [1] 71000
# [1] 72000
# [1] 73000
# [1] 74000
# [1] 75000
# [1] 76000
# [1] 77000
# [1] 78000
# [1] 79000
# [1] 80000
# [1] 81000
# [1] 82000
# [1] 83000
# [1] 84000
# [1] 85000
# [1] 86000
# [1] 87000
# [1] 88000
# [1] 89000
# [1] 90000
# [1] 91000
# [1] 92000
# [1] 93000
# [1] 94000
# [1] 95000
# [1] 96000
# [1] 97000
# [1] 98000
# [1] 99000
# [1] 100000
#        Metabolism  Quiescent  Activated  Interferon Acute.Activation
# GCSF    0.4034853 0.31400804 0.26139410 0.007037534     0.0000000000
# ct      0.3378011 0.35881181 0.28183300 0.007245064     0.0000000000
# dmPGE2  0.1743697 0.05042017 0.22689076 0.000000000     0.5483193277
# indo    0.3123000 0.32278706 0.34607181 0.010309278     0.0001777462
# pIC     0.2513369 0.24598930 0.07754011 0.422459893     0.0000000000
#         Cell.cycle
# GCSF   0.014075067
# ct     0.014309002
# dmPGE2 0.000000000
# indo   0.008354070
# pIC    0.002673797

# %%
# %%R
# ### P-value tests for different treatments
#
#
# print('GCSF')
# print(two.class.test(obs.counts, tip.exp, cond.control="ct", cond.treatment="GCSF",to.plot=F))
# print('dmPGE2')
# print(two.class.test(obs.counts, tip.exp, cond.control="ct", cond.treatment="dmPGE2",to.plot=F))
# print('pIC')
# print(two.class.test(obs.counts, tip.exp, cond.control="ct", cond.treatment="pIC",to.plot=F))
# print('indo')
# print(two.class.test(obs.counts, tip.exp, cond.control="ct", cond.treatment="indo",to.plot=F))
# Out:
# [1] "GCSF"
#       Metabolism        Quiescent        Activated       Interferon
#          0.08226          0.16757          0.32153          0.49787
# Acute.Activation       Cell.cycle
#          0.49940          0.48052
# [1] "dmPGE2"
#       Metabolism        Quiescent        Activated       Interferon
#          0.03561          0.00005          0.27202          0.43429
# Acute.Activation       Cell.cycle
#          0.00000          0.15334
# [1] "pIC"
#       Metabolism        Quiescent        Activated       Interferon
#          0.13329          0.07182          0.00111          0.00000
# Acute.Activation       Cell.cycle
#          0.45117          0.19183
# [1] "indo"
#       Metabolism        Quiescent        Activated       Interferon
#          0.25738          0.17509          0.04653          0.37871
# Acute.Activation       Cell.cycle
#          0.46157          0.24265

# %% [markdown]
# ## MPPs

# %%
# read csvs, rename columns, merge and transpose
MPP = pd.read_csv('./write/MPP_cell_numbers.csv', index_col = 0)
MPP = MPP.T
MPP
# Out:
# leiden  Primed  Metabolism  Stem cell  Cell-cycle  Acute-Activation  \
# ct       246.0       223.0      237.0       148.0               8.0
# indo     459.0       385.0      388.0       236.0               5.0
# GCSF     549.0       458.0      420.0       251.0              10.0
# dmPGE2    31.0       334.0      140.0       373.0            1073.0
# pIC      439.0       315.0      246.0       211.0               0.0
#
# leiden  Interferon  Interferon cell-cycle  Myeloid
# ct             2.0                    0.0      2.0
# indo          13.0                    1.0      4.0
# GCSF           4.0                    1.0      9.0
# dmPGE2         1.0                    0.0     40.0
# pIC          713.0                  196.0     20.0

# %%
# %%R -i MPP
# ## Read in file of counts of cells in each population across conditions
#
# obs.counts = as.matrix(MPP)
# print(obs.counts)
# Out:
#        Primed Metabolism Stem.cell Cell.cycle Acute.Activation Interferon
# ct        246        223       237        148                8          2
# indo      459        385       388        236                5         13
# GCSF      549        458       420        251               10          4
# dmPGE2     31        334       140        373             1073          1
# pIC       439        315       246        211                0        713
#        Interferon.cell.cycle Myeloid
# ct                         0       2
# indo                       1       4
# GCSF                       1       9
# dmPGE2                     0      40
# pIC                      196      20

# %%
# %%R
#
# ## Run an example using error (p) of 0.05 and with 100,000 iterations
# tip.exp <- generateNull(obs.counts, n=100000, p=0.1);     # Generate the null distribution based on sampling
#
# print(obs.counts/apply(obs.counts, 1, sum))
# Out:
# [1] 1000
# [1] 2000
# [1] 3000
# [1] 4000
# [1] 5000
# [1] 6000
# [1] 7000
# [1] 8000
# [1] 9000
# [1] 10000
# [1] 11000
# [1] 12000
# [1] 13000
# [1] 14000
# [1] 15000
# [1] 16000
# [1] 17000
# [1] 18000
# [1] 19000
# [1] 20000
# [1] 21000
# [1] 22000
# [1] 23000
# [1] 24000
# [1] 25000
# [1] 26000
# [1] 27000
# [1] 28000
# [1] 29000
# [1] 30000
# [1] 31000
# [1] 32000
# [1] 33000
# [1] 34000
# [1] 35000
# [1] 36000
# [1] 37000
# [1] 38000
# [1] 39000
# [1] 40000
# [1] 41000
# [1] 42000
# [1] 43000
# [1] 44000
# [1] 45000
# [1] 46000
# [1] 47000
# [1] 48000
# [1] 49000
# [1] 50000
# [1] 51000
# [1] 52000
# [1] 53000
# [1] 54000
# [1] 55000
# [1] 56000
# [1] 57000
# [1] 58000
# [1] 59000
# [1] 60000
# [1] 61000
# [1] 62000
# [1] 63000
# [1] 64000
# [1] 65000
# [1] 66000
# [1] 67000
# [1] 68000
# [1] 69000
# [1] 70000
# [1] 71000
# [1] 72000
# [1] 73000
# [1] 74000
# [1] 75000
# [1] 76000
# [1] 77000
# [1] 78000
# [1] 79000
# [1] 80000
# [1] 81000
# [1] 82000
# [1] 83000
# [1] 84000
# [1] 85000
# [1] 86000
# [1] 87000
# [1] 88000
# [1] 89000
# [1] 90000
# [1] 91000
# [1] 92000
# [1] 93000
# [1] 94000
# [1] 95000
# [1] 96000
# [1] 97000
# [1] 98000
# [1] 99000
# [1] 100000
#            Primed Metabolism  Stem.cell Cell.cycle Acute.Activation  Interferon
# ct     0.28406467  0.2575058 0.27367206 0.17090069      0.009237875 0.002309469
# indo   0.30784708  0.2582160 0.26022803 0.15828303      0.003353454 0.008718981
# GCSF   0.32256169  0.2690952 0.24676851 0.14747356      0.005875441 0.002350176
# dmPGE2 0.01556225  0.1676707 0.07028112 0.18724900      0.538654618 0.000502008
# pIC    0.20514019  0.1471963 0.11495327 0.09859813      0.000000000 0.333177570
#        Interferon.cell.cycle     Myeloid
# ct              0.0000000000 0.002309469
# indo            0.0006706908 0.002682763
# GCSF            0.0005875441 0.005287897
# dmPGE2          0.0000000000 0.020080321
# pIC             0.0915887850 0.009345794

# %%
# %%R
# ### P-value tests for different treatments
#
#
# print('GCSF')
# print(two.class.test(obs.counts, tip.exp, cond.control="ct", cond.treatment="GCSF",to.plot=F))
# print('dmPGE2')
# print(two.class.test(obs.counts, tip.exp, cond.control="ct", cond.treatment="dmPGE2",to.plot=F))
# print('pIC')
# print(two.class.test(obs.counts, tip.exp, cond.control="ct", cond.treatment="pIC",to.plot=F))
# print('indo')
# print(two.class.test(obs.counts, tip.exp, cond.control="ct", cond.treatment="indo",to.plot=F))
# Out:
# [1] "GCSF"
#                Primed            Metabolism             Stem.cell
#               0.30856               0.43321               0.36757
#            Cell.cycle      Acute.Activation            Interferon
#               0.36159               0.46020               0.47934
# Interferon.cell.cycle               Myeloid
#               0.44327               0.40429
# [1] "dmPGE2"
#                Primed            Metabolism             Stem.cell
#               0.00008               0.10881               0.00166
#            Cell.cycle      Acute.Activation            Interferon
#               0.39765               0.00000               0.47565
# Interferon.cell.cycle               Myeloid
#               0.46960               0.10900
# [1] "pIC"
#                Primed            Metabolism             Stem.cell
#               0.14366               0.06112               0.01111
#            Cell.cycle      Acute.Activation            Interferon
#               0.12212               0.41777               0.00000
# Interferon.cell.cycle               Myeloid
#               0.00009               0.27611
# [1] "indo"
#                Primed            Metabolism             Stem.cell
#               0.38364               0.49888               0.43097
#            Cell.cycle      Acute.Activation            Interferon
#               0.42664               0.44403               0.43845
# Interferon.cell.cycle               Myeloid
#               0.49611               0.42327

# %%
sc.logging.print_versions()
pd.show_versions()
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.17.3 scipy==1.3.0 pandas==0.25.3 scikit-learn==0.22.2.post1 statsmodels==0.10.0 python-igraph==0.7.1 louvain==0.6.1
#
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.3.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 4.19.76-linuxkit
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 0.25.3
# numpy            : 1.17.3
# pytz             : 2019.3
# dateutil         : 2.8.1
# pip              : 19.3.1
# setuptools       : 41.6.0.post20191101
# Cython           : None
# pytest           : 5.3.5
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.10.3
# IPython          : 7.9.0
# pandas_datareader: None
# bs4              : None
# bottleneck       : None
# fastparquet      : None
# gcsfs            : None
# lxml.etree       : None
# matplotlib       : 3.2.0
# numexpr          : 2.7.1
# odfpy            : None
# openpyxl         : None
# pandas_gbq       : None
# pyarrow          : None
# pytables         : None
# s3fs             : None
# scipy            : 1.3.0
# sqlalchemy       : 1.3.10
# tables           : 3.6.1
# xarray           : None
# xlrd             : None
# xlwt             : None
# xlsxwriter       : None

# %%
# %%R
#
# sessionInfo()
# Out:
# R version 3.6.1 (2019-07-05)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.2 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/lib/libopenblasp-r0.3.7.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] tools     stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
# [1] plyr_1.8.4    ggplot2_3.2.1
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.3       withr_2.1.2      crayon_1.3.4     dplyr_0.8.3
#  [5] assertthat_0.2.1 grid_3.6.1       R6_2.4.0         gtable_0.3.0
#  [9] magrittr_1.5     scales_1.0.0     pillar_1.4.2     rlang_0.4.1
# [13] lazyeval_0.2.2   glue_1.3.1       purrr_0.3.3      munsell_0.5.0
# [17] compiler_3.6.1   pkgconfig_2.0.3  colorspace_1.4-1 tidyselect_0.2.5
# [21] tibble_2.1.3

# %%
# !pip list
